# %% [markdown]
# # DATA ANALYSIS PROJECT JUAN FELIPE LEDESMA

# %% [markdown]
# ## Import the required libraries

# %%
# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
#!pip install -U scikit-learn

# %%
# %pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# !pip install scikit-learn pandas numpy seaborn matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Dataset to python
# Context
# The World Happiness Report is a landmark survey of the state of global happiness . The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.
#
# Content
# The happiness scores and rankings use data from the Gallup World Poll . The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.

# %%
file_path= "/Users/jfledesma/Downloads/WHR2023.csv"
# Load the uploaded CSV file into a DataFrame
file_name = 'WHR2023.csv'
df = pd.read_csv(file_name)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Testing Dataset import

# %%
# command starts from the top of the table. and the 10 is the amount of rows
df.head(10)
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
# 5       Sweden         7.395                           0.037         7.468
# 6       Norway         7.315                           0.044         7.402
# 7  Switzerland         7.240                           0.043         7.324
# 8   Luxembourg         7.228                           0.069         7.363
# 9  New Zealand         7.123                           0.038         7.198
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# ...

# %%
df.shape
# Out:
# (137, 19)

# %%
df.dtypes
# Out:
# Country name                                   object
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy                       float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# ...

# %%
df.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    137.000000                      137.000000    137.000000
# mean       5.539796                        0.064715      5.666526
# std        1.139929                        0.023031      1.117421
# min        1.859000                        0.029000      1.923000
# 25%        4.724000                        0.047000      4.980000
# 50%        5.684000                        0.060000      5.797000
# 75%        6.334000                        0.077000      6.441000
# max        7.804000                        0.147000      7.875000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    137.000000             137.000000      137.000000
# mean       5.412971               9.449796        0.799073
# std        1.163724               1.207302        0.129222
# min        1.795000               5.527000        0.341000
# 25%        4.496000               8.591000        0.722000
# ...

# %%
df.head()
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# 1         7.506                 10.962           0.954
# 2         7.434                 10.896           0.983
# 3         7.411                 10.639           0.943
# 4         7.346                 10.942           0.930
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                   71.150                         0.961      -0.019
# ...

# %% [markdown]
# ## Wragling and cleaning Data

# %%
# Drop the specified columns
df.drop(columns=["Explained by: Generosity", "Social support", "Country name", 
                 "Standard error of ladder score", "upperwhisker", "lowerwhisker", 
                 "Ladder score in Dystopia", "Explained by: Log GDP per capita", 
                 "Explained by: Social support", "Explained by: Healthy life expectancy", 
                 "Explained by: Freedom to make life choices", "Explained by: Perceptions of corruption", 
                 "Dystopia + residual"], axis=1, inplace=True)

# Display statistical summary of the remaining data

print(df.head())
# Out:
#    Ladder score  Logged GDP per capita  Healthy life expectancy  \
# 0         7.804                 10.792                   71.150
# 1         7.586                 10.962                   71.250
# 2         7.530                 10.896                   72.050
# 3         7.473                 10.639                   72.697
# 4         7.403                 10.942                   71.550
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.961      -0.019                      0.182
# 1                         0.934       0.134                      0.196
# 2                         0.936       0.211                      0.668
# 3                         0.809      -0.023                      0.708
# 4                         0.887       0.213                      0.379

# %%
print("number of NaN values for the column Ladder score:", df['Ladder score'].isnull().sum())
print("number of NaN values for the column Logged GDP per capita :", df['Logged GDP per capita'].isnull().sum())
print("number of NaN values for the column Healthy life expectancy :", df['Healthy life expectancy'].isnull().sum())
print("number of NaN values for the column Freedom to make life choices :", df['Freedom to make life choices'].isnull().sum())
print("number of NaN values for the column Generosity:", df['Generosity'].isnull().sum())
print("number of NaN values for the column Perceptions of corruption :", df['Perceptions of corruption'].isnull().sum())
# Out:
# number of NaN values for the column Ladder score: 0
# number of NaN values for the column Logged GDP per capita : 0
# number of NaN values for the column Healthy life expectancy : 1
# number of NaN values for the column Freedom to make life choices : 0
# number of NaN values for the column Generosity: 0
# number of NaN values for the column Perceptions of corruption : 0

# %%
mean=df['Healthy life expectancy'].mean()
df['Healthy life expectancy'].replace(np.nan,mean, inplace=True)

# %%
print("number of NaN values for the column Ladder score:", df['Ladder score'].isnull().sum())
print("number of NaN values for the column Logged GDP per capita :", df['Logged GDP per capita'].isnull().sum())
print("number of NaN values for the column Healthy life expectancy :", df['Healthy life expectancy'].isnull().sum())
print("number of NaN values for the column Freedom to make life choices :", df['Freedom to make life choices'].isnull().sum())
print("number of NaN values for the column Generosity:", df['Generosity'].isnull().sum())
print("number of NaN values for the column Perceptions of corruption :", df['Perceptions of corruption'].isnull().sum())
# Out:
# number of NaN values for the column Ladder score: 0
# number of NaN values for the column Logged GDP per capita : 0
# number of NaN values for the column Healthy life expectancy : 0
# number of NaN values for the column Freedom to make life choices : 0
# number of NaN values for the column Generosity: 0
# number of NaN values for the column Perceptions of corruption : 0

# %% [markdown]
# ## Testing some PLOTS

# %%
#Colors to be used in the plots
color=["#f94144","#f3722c","#f8961e","#f9c74f","#90be6d","#43aa8b","#577590"]
sns.palplot(color)

# %%
# Bin Logged GDP per capita into categories (e.g., Low, Medium, High)
df['GDP_Category'] = pd.qcut(df['Logged GDP per capita'], q=3, labels=['Low', 'Medium', 'High'])

# Create a boxplot to compare Ladder score distribution by GDP category
sns.boxplot(x="GDP_Category", y="Ladder score", data=df)

# Add labels and title for clarity
plt.xlabel("GDP Category (Low, Medium, High)")
plt.ylabel("Ladder Score (Happiness)")
plt.title("Ladder Score Distribution by GDP Category")

# Display the plot
plt.show()

# %%
# Create regression plots for each predictor vs Ladder score
predictors = ['Logged GDP per capita', 'Healthy life expectancy', 'Freedom to make life choices', 
              'Generosity', 'Perceptions of corruption']

plt.figure(figsize=(15, 10))
for i, predictor in enumerate(predictors, 1):
    plt.subplot(2, 3, i)
    sns.regplot(x=predictor, y='Ladder score', data=df, ci=None)  # ci=None to simplify plot
    plt.xlabel(predictor)
    plt.ylabel('Ladder Score (Happiness)')
    plt.title(f'Regression Plot: {predictor} vs Ladder Score')

# Adjust layout and display
plt.tight_layout()
plt.show()

# %%
df_numeric = df.select_dtypes(include=[np.number])
df_numeric.corr()['Ladder score'].sort_values()
# Out:
# Perceptions of corruption      -0.471911
# Generosity                      0.044082
# Freedom to make life choices    0.662924
# Healthy life expectancy         0.746078
# Logged GDP per capita           0.784367
# Ladder score                    1.000000
# Name: Ladder score, dtype: float64

# %%
# Prepare the data for single-variable model
X_single = df[['Logged GDP per capita']]
y = df['Ladder score']

# Fit the linear regression model (single-variable)
model_single = LinearRegression()
model_single.fit(X_single, y)

# Calculate R² for single-variable model
r_squared_single = model_single.score(X_single, y)

# Prepare the data for multi-variable model
X_multi = df[['Logged GDP per capita', 'Healthy life expectancy', 'Freedom to make life choices', 
              'Generosity', 'Perceptions of corruption']]

# Fit the linear regression model (multi-variable)
model_multi = LinearRegression()
model_multi.fit(X_multi, y)

# Calculate R² for multi-variable model
r_squared_multi = model_multi.score(X_multi, y)

# Print the R² values
print(f"R² Score (Single-variable, Logged GDP per capita): {r_squared_single:.4f}")
print(f"R² Score (Multi-variable): {r_squared_multi:.4f}")
# Out:
# R² Score (Single-variable, Logged GDP per capita): 0.6152
# R² Score (Multi-variable): 0.7628

# %%
# Prepare the data
X = df[['Logged GDP per capita', 'Healthy life expectancy', 'Freedom to make life choices', 
        'Generosity', 'Perceptions of corruption']]  # Features
y = df['Ladder score']  # Target variable

# Fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Calculate R²
r_squared = model.score(X, y)

# Print the R² value
print(f"R² Score: {r_squared:.4f}")
# Out:
# R² Score: 0.7628

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Create the list of tuples
estimators = [
    ('scale', StandardScaler()),
    ('polynomial', PolynomialFeatures(include_bias=False)),
    ('model', LinearRegression())
]

# Print the list to verify
print(estimators)
# Out:
# [('scale', StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
# Create the pipeline
pipeline = Pipeline(estimators)

# Prepare the data
features = ['Logged GDP per capita', 'Healthy life expectancy', 'Freedom to make life choices', 
            'Generosity', 'Perceptions of corruption']
X = df[features]  # Features
y = df['Ladder score']  # Target variable

# Fit the pipeline
pipeline.fit(X, y)

# Calculate R²
r_squared = pipeline.score(X, y)

# Print the R² value
print(f"R² Score: {r_squared:.4f}")
# Out:
# R² Score: 0.8121

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
print("done")
# Out:
# done

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)

# Print the number of samples
print("number of test samples:", x_test.shape[0])
print("number of training samples:", x_train.shape[0])
# Out:
# number of test samples: 21
# number of training samples: 116

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=0.1)  # Set regularization parameter to 0.1
ridge_model.fit(x_train, y_train)

# Calculate R² using the test data
r_squared_test = ridge_model.score(x_test, y_test)

# Print the R² value
print(f"R² Score on Test Set: {r_squared_test:.4f}")
# Out:
# R² Score on Test Set: 0.6661

# %%
# Perform second-order polynomial transform on training and test data
poly = PolynomialFeatures(degree=2, include_bias=False)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

# Create and fit the Ridge regression object
ridge_model = Ridge(alpha=0.1)
ridge_model.fit(x_train_poly, y_train)

# Calculate R² using the test data
r_squared_test = ridge_model.score(x_test_poly, y_test)

# Print the R² value
print(f"R² Score on Test Set: {r_squared_test:.4f}")
# Out:
# R² Score on Test Set: 0.6695

# %%
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
# Define the parameter grid for alpha
param_grid = {'alpha': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]}

# Initialize Ridge Regression model
ridge = Ridge()

# Perform grid search with 5-fold cross-validation
grid_search = GridSearchCV(ridge, param_grid, cv=5, scoring='r2', return_train_score=True)
grid_search.fit(x_train, y_train)

# Get the best model and hyperparameter
best_alpha = grid_search.best_params_['alpha']
best_model = grid_search.best_estimator_

# Predict on test set with the best model
y_pred = best_model.predict(x_test)

# Calculate R² on test set
r2_test = r2_score(y_test, y_pred)

# Print results
print(f"Best alpha: {best_alpha}")
print(f"Cross-validated R² (training): {grid_search.best_score_:.4f}")
print(f"R² Score on test set: {r2_test:.4f}")

# Optional: Visualize the impact of alpha on cross-validated R²
results = pd.DataFrame(grid_search.cv_results_)
plt.figure(figsize=(10, 6))
plt.plot(param_grid['alpha'], results['mean_test_score'], marker='o')
plt.xscale('log')
plt.xlabel('Alpha (log scale)')
plt.ylabel('Cross-Validated R² Score')
plt.title('R² Score vs Alpha for Ridge Regression')
plt.grid(True)
plt.show()
# Out:
# Best alpha: 0.01
# Cross-validated R² (training): 0.7302
# R² Score on test set: 0.6595

# %% [markdown]
# #### Contextual Analysis
# Model Fit: The combination of RMSE (~0.5-1.0), MAE (~0.4-0.8), and R² (~0.6-0.7) suggests a decent linear fit. The errors are small relative to the 0-10 range, and the R² indicates the features are predictive, though not exhaustive.
# Comparison to Ridge: Your Ridge Regression test R² of 0.6595 is very close to the expected Linear Regression R², implying that minimal regularization (alpha=0.01) didn’t drastically alter the linear model’s performance. The pipeline’s higher R² (0.8121) likely stems from polynomial features, suggesting non-linearity in the data.
# Implications: The model performs well for a linear approach, but the gap between training (e.g., pipeline) and test R² (e.g., Ridge/Linear) highlights the need for non-linear models or feature engineering to close the generalization gap.

# %%
import joblib  # For saving the model
import matplotlib.pyplot as plt
model_filename = 'ridge_regression_model.joblib'
joblib.dump(best_model, model_filename)
print(f"Model saved as {model_filename}")
# Out:
# Model saved as ridge_regression_model.joblib

# %% [markdown]
# ## Conclusion
# #### Countries having good Healthly life, Social support, Freedom to make life choised, less corruptions, good per capita income have high happiness index
